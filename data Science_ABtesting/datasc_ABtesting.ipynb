# %%
#evaluating changes---comparing performance, with treatment and control, effective changes for data driven dscision
#optimising a product and a service, validating hypothesis, with deeper understanding of a product.

# %%
#AB test basics
# hypothesis of the AB test/ primary metrics
# design tes/power analysis---solutions can influence KPI
# run A/B test
# Result Analysis/Statistical significance
# """""""""""""""" Practical significance

#1 selection of primary metric-- metric validity Question
#statistical hypothesis

# %%
#A/B testing Design---not about testing but about learning
#power analysis, minimum sample size, test duration
#power analysis- determine the power of the test.

# %%
#AB testing for control and experimental button  to ensure highly enguaging users for the click rate.
#clickthrough rate as a primary metric
#
